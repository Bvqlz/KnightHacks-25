# %%
# !pip install geopandas numpy ortools matplotlib
import geopandas as gpd
import numpy as np
import pandas as pd
from shapely import wkt
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
import functools



# --- Load data ---
print("=== Loading Data ===")
distance_matrix = np.load('distance_matrix.npy')
asset_indexes = np.load('asset_indexes.npy')
photo_indexes = np.load('photo_indexes.npy')
points_lat_long = np.load('points_lat_long.npy')
predecessors = np.load('predecessors.npy')
waypoint_indexes = np.load('waypoint_indexes.npy')

print(f"distance_matrix: {distance_matrix.shape}")
print(f"asset_indexes: {asset_indexes}")
print(f"photo_indexes: {photo_indexes}")
print(f"points_lat_long: {points_lat_long.shape}")
print(f"predecessors: {predecessors.shape}")
print(f"waypoint_indexes: {waypoint_indexes}")

# --- Understand the data structure ---
num_navigable = distance_matrix.shape[0]  # 2779 waypoints we can visit
num_total_points = points_lat_long.shape[0]  # 4274 total points
num_assets = asset_indexes[1] - asset_indexes[0] + 1  # Assets (not navigable)
num_photos = photo_indexes[1] - photo_indexes[0] + 1  # Photo waypoints (navigable)

print(f"\n=== Data Structure ===")
print(f"Total points in coordinate list: {num_total_points}")
print(f"Navigable waypoints (in distance matrix): {num_navigable}")
print(f"Photo waypoints: {num_photos} (indices {photo_indexes[0]} to {photo_indexes[1]})")
print(f"Asset points: {num_assets} (indices {asset_indexes[0]} to {asset_indexes[1]})")
print(f"Note: Assets are NOT in distance matrix - they're reference points only")

# --- Visualize the problem ---
try:
    # Separate navigable waypoints from asset locations
    navigable_coords = points_lat_long[:num_navigable]
    asset_coords = points_lat_long[asset_indexes[0]:asset_indexes[1]+1]
    
    fig, ax = plt.subplots(figsize=(12, 10))
    
    # Load polygon boundary
    try:
        with open("polygon_lon_lat.wkt") as f:
            polygon = wkt.loads(f.read())
        gdf_poly = gpd.GeoDataFrame(geometry=[polygon], crs="EPSG:4326")
        gdf_poly.plot(ax=ax, edgecolor='blue', facecolor='none', linewidth=2)
    except FileNotFoundError:
        print("Polygon file not found")
    
    # Plot navigable waypoints (red) and assets (green)
    ax.scatter(navigable_coords[:, 0], navigable_coords[:, 1], 
               c='red', s=10, alpha=0.5, label=f'Navigable waypoints ({num_navigable})')
    ax.scatter(asset_coords[:, 0], asset_coords[:, 1], 
               c='green', s=50, marker='s', alpha=0.7, label=f'Assets ({num_assets})')
    
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.set_title('Drone Inspection Area')
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
except Exception as e:
    print(f"Visualization error: {e}")

# --- Create data model ---
def create_data_model(subset_size=None):
    """Stores the data for the problem."""
    data = {}
    
    # Option to solve smaller subset for testing
    if subset_size and subset_size < num_navigable:
        print(f"\n⚠️  Using subset of {subset_size} waypoints for faster solving")
        data["distance_matrix"] = distance_matrix[:subset_size, :subset_size].astype(np.int32)
        data["num_waypoints"] = subset_size
    else:
        data["distance_matrix"] = distance_matrix.astype(np.int32)
        data["num_waypoints"] = num_navigable
    
    data["num_vehicles"] = 1
    data["depot"] = 0  # Starting waypoint
    
    # Calculate reasonable max distance
    total_dist = np.sum(distance_matrix)
    avg_dist = np.mean(distance_matrix[distance_matrix > 0])
    max_dist = int(avg_dist * data["num_waypoints"] * 1.5)
    
    data["max_distance"] = max_dist
    
    print(f"\nDistance matrix stats:")
    print(f"  Min distance: {np.min(distance_matrix[distance_matrix > 0]):.1f}m")
    print(f"  Max distance: {np.max(distance_matrix):.1f}m")
    print(f"  Avg distance: {avg_dist:.1f}m")
    print(f"  Set max route: {max_dist:.1f}m")
    
    return data


def print_solution(data, manager, routing, solution, points_lat_long):
    """Prints solution details."""
    print("\n" + "="*50)
    print("=== SOLUTION FOUND ===")
    print("="*50)
    print(f"Objective value (total distance): {solution.ObjectiveValue():,.0f}m")
    print(f"                                   {solution.ObjectiveValue()/1000:.2f}km")
    
    route = []
    index = routing.Start(0)
    route_distance = 0
    
    print(f"\nRoute visiting {data['num_waypoints']} waypoints:")
    print("(Showing first 10 and last 10 waypoints...)\n")
    
    waypoint_count = 0
    while not routing.IsEnd(index):
        node = manager.IndexToNode(index)
        route.append(node)
        
        if waypoint_count < 10 or waypoint_count >= data['num_waypoints'] - 10:
            coord = points_lat_long[node]
            print(f"  {waypoint_count:4d}. Waypoint {node:4d}: [{coord[0]:.6f}, {coord[1]:.6f}]")
        elif waypoint_count == 10:
            print(f"  ... ({data['num_waypoints'] - 20} waypoints omitted) ...")
        
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
        waypoint_count += 1
    
    # Add final node (return to depot)
    final_node = manager.IndexToNode(index)
    route.append(final_node)
    coord = points_lat_long[final_node]
    print(f"  {waypoint_count:4d}. Waypoint {final_node:4d}: [{coord[0]:.6f}, {coord[1]:.6f}] (END)")
    
    print(f"\n{'='*50}")
    print(f"Total route distance: {route_distance:,.0f}m ({route_distance/1000:.2f}km)")
    print(f"Total waypoints visited: {len(route)}")
    print(f"{'='*50}\n")
    
    return route


def visualize_route(route, points_lat_long, sample_rate=10):
    """Visualize the optimized route (sampling for large routes)."""
    route_coords = points_lat_long[route]
    
    # Sample route for visualization if too large
    if len(route) > 500:
        sampled_indices = list(range(0, len(route), sample_rate))
        if sampled_indices[-1] != len(route) - 1:
            sampled_indices.append(len(route) - 1)
        route_coords_plot = route_coords[sampled_indices]
        print(f"Visualizing {len(sampled_indices)} of {len(route)} waypoints")
    else:
        route_coords_plot = route_coords
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))
    
    # Left plot: Full context
    ax1.scatter(points_lat_long[:num_navigable, 0], points_lat_long[:num_navigable, 1], 
                c='lightgray', s=5, alpha=0.3, label='All waypoints')
    ax1.plot(route_coords_plot[:, 0], route_coords_plot[:, 1], 
             'b-', linewidth=1.5, alpha=0.7, label='Route')
    ax1.scatter(route_coords[0, 0], route_coords[0, 1], 
                c='green', s=200, marker='*', label='Start', zorder=5)
    ax1.scatter(route_coords[-1, 0], route_coords[-1, 1], 
                c='red', s=200, marker='X', label='End', zorder=5)
    ax1.set_xlabel('Longitude')
    ax1.set_ylabel('Latitude')
    ax1.set_title('Complete Route Overview')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Right plot: Route detail (first 100 waypoints)
    detail_size = min(100, len(route_coords))
    ax2.plot(route_coords[:detail_size, 0], route_coords[:detail_size, 1], 
             'b-o', linewidth=1, markersize=3, alpha=0.7)
    ax2.scatter(route_coords[0, 0], route_coords[0, 1], 
                c='green', s=200, marker='*', label='Start', zorder=5)
    ax2.set_xlabel('Longitude')
    ax2.set_ylabel('Latitude')
    ax2.set_title(f'Route Detail (First {detail_size} Waypoints)')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()


def main(use_subset=False, subset_size=500):
    """Entry point of the program."""
    
    # For testing with large dataset, use a subset
    data = create_data_model(subset_size if use_subset else None)
    
    print(f"\n{'='*50}")
    print("=== OPTIMIZATION PARAMETERS ===")
    print(f"{'='*50}")
    print(f"Number of waypoints to visit: {data['num_waypoints']}")
    print(f"Number of vehicles (drones): {data['num_vehicles']}")
    print(f"Maximum route distance: {data['max_distance']:,.0f}m ({data['max_distance']/1000:.1f}km)")
    print(f"Starting depot: Waypoint {data['depot']}")
    print(f"{'='*50}\n")
    
    # Create the routing index manager
    manager = pywrapcp.RoutingIndexManager(
        len(data["distance_matrix"]), 
        data["num_vehicles"], 
        data["depot"]
    )
    
    # Create Routing Model
    routing = pywrapcp.RoutingModel(manager)
    
    # Create and register a transit callback
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data["distance_matrix"][from_node][to_node]
    
    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    
    # Define cost of each arc
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)
    
    # Add Distance constraint
    dimension_name = "Distance"
    routing.AddDimension(
        transit_callback_index,
        0,  # no slack
        data["max_distance"],  # vehicle maximum travel distance
        True,  # start cumul to zero
        dimension_name,
    )
    distance_dimension = routing.GetDimensionOrDie(dimension_name)
    distance_dimension.SetGlobalSpanCostCoefficient(100)
    
    # Setting search parameters
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
    )
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
    )
    search_parameters.time_limit.seconds = 60  # Increase for larger problems
    search_parameters.log_search = True  # Show progress
    
    print("🚁 Starting route optimization...")
    print("(This may take a while for 2779 waypoints...)\n")

    import pickle
    from pathlib import Path

    def cache_save(key, result, cache_dir="cache"):
        Path(cache_dir).mkdir(exist_ok=True)
        with open(f"{cache_dir}/{key}.pkl", "wb") as f:
            pickle.dump(result, f)

    def cache_load(key, cache_dir="cache"):
        file = Path(f"{cache_dir}/{key}.pkl")
        if file.exists():
            with open(file, "rb") as f:
                return pickle.load(f)
        return None


    def findSolution():
        key = "8675309"  # arbitrary cache key; ideally generate dynamically
        cached = cache_load(key)

        if cached is None:
            print("No cache found. Solving fresh...")
            solution = routing.SolveWithParameters(search_parameters)
            cache_save(key, solution)
            return solution
        else:
            print("Loaded cached solution.")
            return cached

    # Solve the problem
    solution = findSolution()
    
    # Print and visualize solution
    if solution:
        route = print_solution(data, manager, routing, solution, points_lat_long)
        
        # Save route to file
        np.save('optimized_route.npy', np.array(route))
        print(f"✅ Route saved to 'optimized_route.npy'")
        
        # Visualize
        visualize_route(route, points_lat_long)
        
        return route
    else:
        print("❌ No solution found!")
        print("\nTroubleshooting:")
        print("1. The max_distance constraint may be too restrictive")
        print("2. Try running with use_subset=True first")
        print("3. Increase time_limit in search_parameters")
        return None


if __name__ == "__main__":
    # For initial testing with 2779 waypoints, start with a subset
    print("Choose mode:")
    print("1. Test with 500 waypoints (fast, ~1 min)")
    print("2. Full optimization with all 2779 waypoints (slow, ~5-10 min)")
    
    # Change this to False to run full optimization
    TEST_MODE = True
    
    if TEST_MODE:
        print("\n🧪 Running in TEST MODE (500 waypoints)\n")
        route = main(use_subset=True, subset_size=500)
    else:
        print("\n🚀 Running FULL OPTIMIZATION (2779 waypoints)\n")
        route = main(use_subset=False)
# Out:
# Requirement already satisfied: geopandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.1.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.2.6)
# Requirement already satisfied: ortools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (9.14.6206)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: pyogrio>=0.7.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from geopandas) (2.3.1)
# Requirement already satisfied: pyproj>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: absl-py>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ortools) (2.3.1)
# Requirement already satisfied: protobuf<6.32,>=6.31.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ortools) (6.31.1)
# Requirement already satisfied: typing-extensions>=4.12 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ortools) (4.14.1)
# Requirement already satisfied: immutabledict>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ortools) (4.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# === Loading Data ===
# distance_matrix: (2779, 2779)
# asset_indexes: [3544 4274]
# photo_indexes: [   0 2779]
# points_lat_long: (4274, 2)
# predecessors: (2779, 3544)
# waypoint_indexes: [2779 3544]
#
# === Data Structure ===
# Total points in coordinate list: 4274
# Navigable waypoints (in distance matrix): 2779
# Photo waypoints: 2780 (indices 0 to 2779)
# Asset points: 731 (indices 3544 to 4274)
# Note: Assets are NOT in distance matrix - they're reference points only
# Visualization error: name 'plt' is not defined
# Choose mode:
# 1. Test with 500 waypoints (fast, ~1 min)
# 2. Full optimization with all 2779 waypoints (slow, ~5-10 min)
#
# 🧪 Running in TEST MODE (500 waypoints)
#
#
# ⚠️  Using subset of 500 waypoints for faster solving
#
# Distance matrix stats:
#   Min distance: 0.6m
#   Max distance: 29410.9m
#   Avg distance: 9029.5m
#   Set max route: 6772123.0m
#
# ==================================================
# === OPTIMIZATION PARAMETERS ===
# ==================================================
# Number of waypoints to visit: 500
# Number of vehicles (drones): 1
# Maximum route distance: 6,772,123m (6772.1km)
# Starting depot: Waypoint 0
# ==================================================
#
# 🚁 Starting route optimization...
# (This may take a while for 2779 waypoints...)
#
# No cache found. Solving fresh...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761415501.615104 2371954 search.cc:310] Start search (memory used = 244.62 MB)
# I0000 00:00:1761415501.616051 2371954 search.cc:310] Root node processed (time = 0 ms, constraints = 3011, memory used = 244.97 MB)
# I0000 00:00:1761415501.724031 2371954 search.cc:310] Solution #0 (5004247, time = 108 ms, branches = 35, failures = 1, depth = 33, memory used = 249.64 MB, limit = 0%)
# I0000 00:00:1761415501.811035 2371954 search.cc:310] Solution #1 (5003237, improvement rate = -0.231987%/s, maximum = 5004247, time = 195 ms, branches = 39, failures = 3, depth = 33, LinKernighan, neighbors = 1, filtered neighbors = 1, accepted neighbors = 1, memory used = 250.52 MB, limit = 0%)
# I0000 00:00:1761415501.813444 2371954 search.cc:310] Solution #2 (5000308, improvement rate = -29.271%/s, maximum = 5004247, time = 197 ms, branches = 44, failures = 5, depth = 33, LinKernighan, neighbors = 3, filtered neighbors = 2, accepted neighbors = 2, memory used = 250.52 MB, limit = 0%)
# I0000 00:00:1761415501.815892 2371954 search.cc:310] Solution #3 (5000106, improvement rate = -2.01988%/s, maximum = 5004247, time = 200 ms, branches = 48, failures = 7, depth = 33, LinKernighan, neighbors = 5, filtered neighbors = 3, accepted neighbors = 3, memory used = 250.52 MB, limit = 0%)
# I0000 00:00:1761415530.010919 2371954 search.cc:310] Solution #224 (4332698, improvement rate = -1.16553%/s, maximum = 5004247, time = 28395 ms, branches = 1152, failures = 449, depth = 33, TwoOpt, neighbors = 212145, filtered neighbors = 224, accepted neighbors = 224, memory used = 45.05 MB, limit = 47%)
# I0000 00:00:1761415531.578178 2371954 search.cc:310] Solution #225 (4332294, improvement rate = -0.00595051%/s, maximum = 5004247, time = 29962 ms, branches = 1156, failures = 451, depth = 33, TwoOpt, neighbors = 229368, filtered neighbors = 225, accepted neighbors = 225, memory used = 44.44 MB, limit = 49%)
# I0000 00:00:1761415531.713930 2371954 search.cc:310] Solution #226 (4328961, improvement rate = -0.56988%/s, maximum = 5004247, time = 30098 ms, branches = 1161, failures = 453, depth = 33, TwoOpt, neighbors = 231095, filtered neighbors = 226, accepted neighbors = 226, memory used = 44.61 MB, limit = 50%)
# I0000 00:00:1761415546.789764 2371954 search.cc:310] Solution #227 (4328254, improvement rate = -0.00108337%/s, maximum = 5004247, time = 45173 ms, branches = 1165, failures = 455, depth = 33, TwoOpt, neighbors = 353589, filtered neighbors = 227, accepted neighbors = 227, memory used = 44.69 MB, limit = 75%)
# I0000 00:00:1761415546.792380 2371954 search.cc:310] Solution #228 (4316336, improvement rate = -137.677%/s, maximum = 5004247, time = 45176 ms, branches = 1171, failures = 457, depth = 33, TwoOpt, neighbors = 353616, filtered neighbors = 228, accepted neighbors = 228, memory used = 44.69 MB, limit = 75%)
# I0000 00:00:1761415546.794670 2371954 search.cc:310] Solution #229 (4314619, improvement rate = -19.8896%/s, maximum = 5004247, time = 45178 ms, branches = 1175, failures = 459, depth = 33, TwoOpt, neighbors = 353621, filtered neighbors = 229, accepted neighbors = 229, memory used = 44.69 MB, limit = 75%)
# I0000 00:00:1761415561.601759 2371954 search.cc:310] Finished search tree (time = 59985 ms, branches = 1179, failures = 491, neighbors = 475556, filtered neighbors = 229, accepted neigbors = 229, memory used = 44.81 MB)
# I0000 00:00:1761415561.602003 2371954 search.cc:310] End search (time = 59986 ms, branches = 1179, failures = 491, memory used = 45.05 MB, speed = 19 branches/s)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 326
#     324 if TEST_MODE:
#     325     print("\n🧪 Running in TEST MODE (500 waypoints)\n")
# --> 326     route = main(use_subset=True, subset_size=500)
#     327 else:
#     328     print("\n🚀 Running FULL OPTIMIZATION (2779 waypoints)\n")
#
# Cell In[4], line 292, in main(use_subset, subset_size)
#     289         return cached
#     291 # Solve the problem
# --> 292 solution = findSolution()
#     294 # Print and visualize solution
#     295 if solution:
#
# Cell In[4], line 285, in main.<locals>.findSolution()
#     283     print("No cache found. Solving fresh...")
#     284     solution = routing.SolveWithParameters(search_parameters)
# --> 285     cache_save(key, solution)
#     286     return solution
#     287 else:
#
# Cell In[4], line 268, in main.<locals>.cache_save(key, result, cache_dir)
#     266 Path(cache_dir).mkdir(exist_ok=True)
#     267 with open(f"{cache_dir}/{key}.pkl", "wb") as f:
# --> 268     pickle.dump(result, f)
#
# TypeError: cannot pickle 'SwigPyObject' object
