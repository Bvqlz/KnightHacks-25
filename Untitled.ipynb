# %%
# !pip install geopandas
# !pip install numpy
# !pip install geodatasets
import geopandas
from geodatasets import get_path
import numpy as np
import pandas as pd



distance_matrix = np.load('distance_matrix.npy')
asset_indexes = np.load('asset_indexes.npy')
photo_indexes = np.load('photo_indexes.npy')
points_lat_long = np.load('points_lat_long.npy')
#polygon_lon_lat = np.load("polygon_lon_lat.wkt")
# load later with geopandas
predecessors = np.load('predecessors.npy')
waypoint_indexes = np.load("waypoint_indexes.npy")
print("The shape of the distance matrix is " distance_matrix.shape)
print(asset_indexes.shape)
print(photo_indexes.shape)
print(points_lat_long.shape)
#print(polygon_lon_lat.shape)
print(predecessors.shape)
print(waypoint_indexes.shape)

converting all np files into pandas
dataDictionary = {distance_matrix, asset_indexes, photo_indexes, points_lat_long, polygon_lon_lat ,predecessors, waypoint_indexes}

for i, arr in enumerate(list_of_arrays):
    dataDictionary[f'df{i}'] = pd.DataFrame(arr, columns=['x', 'y', 'value'])


gdf1 = geopandas.read_file(dataDictionary[df1])
gdf2 = geopandas.read_file(dataDictionary[df2])
gdf3 = geopandas.read_file(dataDictionary[df3])
gdf4 = geopandas.read_file(dataDictionary[df4])
gdf5 = geopandas.read_file(dataDictionary[df5])
gdf6 = geopandas.read_file(dataDictionary[df6])

# we want the boundaries on the following polfo

#puts all np files into a dictionary, easy to access.
#key- well, the order that the objects were called, thats the df number, starting at 1. theres 5.

#path_to_data = get_path("")
#gdf = geopandas.read_file(path_to_data)
# Out:
#   Cell In[3], line 19
#     print("The shape of the distance matrix is " distance_matrix.shape)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
